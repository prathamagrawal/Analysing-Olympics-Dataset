# %%
import pandas as pd
import numpy as np
import seaborn as sn
import pandas_profiling
from  sklearn.preprocessing import  LabelEncoder
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("./archive/main.csv")
data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal
# 0          Basketball               Basketball Men's Basketball   NaN
# 1                Judo              Judo Men's Extra-Lightweight   NaN
# 2            Football                   Football Men's Football   NaN
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   NaN
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   NaN
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   NaN
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   NaN
# 271114      Bobsleigh                      Bobsleigh Men's Four   NaN
# 271115      Bobsleigh                      Bobsleigh Men's Four   NaN
#
# [271116 rows x 15 columns]

# %%
data=data.drop(['ID','Height','Weight','NOC','City','Event'],axis=1)

# %%
data['Medal'].fillna(value=0, inplace=True)
data['Medal']=data['Medal'].replace('Gold',3)
data['Medal']=data['Medal'].replace('Silver',2)
data['Medal']=data['Medal'].replace('Bronze',1)

# %%
data.isnull().sum()
# Out:
# Name         0
# Sex          0
# Age       9474
# Team         0
# Games        0
# Year         0
# Season       0
# Sport        0
# Medal        0
# dtype: int64

# %%
# run the profile report
#profile = data.profile_report(title='Pandas Profiling Report')
   
# save the report as html file
#profile.to_file(output_file="pandas_profiling1.html")

# %%
dataplot = sn.heatmap(data.corr(), cmap="OrRd")
plt.show()
# Out:
# <ipython-input-9-091a00d7d2aa>:2: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %% [markdown]
# We are counting the winter season data of the years which coincided with the summer season data.

# %%
data
# Out:
#                             Name Sex   Age            Team        Games  Year  \
# 0                      A Dijiang   M  24.0           China  1992 Summer  1992
# 1                       A Lamusi   M  23.0           China  2012 Summer  2012
# 2            Gunnar Nielsen Aaby   M  24.0         Denmark  1920 Summer  1920
# 3           Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  1900 Summer  1900
# 4       Christine Jacoba Aaftink   F  21.0     Netherlands  1988 Winter  1988
# ...                          ...  ..   ...             ...          ...   ...
# 271111                Andrzej ya   M  29.0        Poland-1  1976 Winter  1976
# 271112                  Piotr ya   M  27.0          Poland  2014 Winter  2014
# 271113                  Piotr ya   M  27.0          Poland  2014 Winter  2014
# 271114        Tomasz Ireneusz ya   M  30.0          Poland  1998 Winter  1998
# 271115        Tomasz Ireneusz ya   M  34.0          Poland  2002 Winter  2002
#
#         Season          Sport  Medal
# 0       Summer     Basketball      0
# 1       Summer           Judo      0
# 2       Summer       Football      0
# 3       Summer     Tug-Of-War      3
# 4       Winter  Speed Skating      0
# ...        ...            ...    ...
# 271111  Winter           Luge      0
# 271112  Winter    Ski Jumping      0
# 271113  Winter    Ski Jumping      0
# 271114  Winter      Bobsleigh      0
# 271115  Winter      Bobsleigh      0
#
# [271116 rows x 9 columns]

# %%
tokyo=pd.read_csv("2020_tokyo_olympics.csv")
tokyo.drop("Unnamed: 0",axis=1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-b7e130f03cca> in <module>
# ----> 1 tokyo=pd.read_csv("2020_tokyo_olympics.csv")
#       2 tokyo.drop("Unnamed: 0",axis=1)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/ECG/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/homebrew/Caskroom/miniforge/base/envs/ECG/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /opt/homebrew/Caskroom/miniforge/base/envs/ECG/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /opt/homebrew/Caskroom/miniforge/base/envs/ECG/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /opt/homebrew/Caskroom/miniforge/base/envs/ECG/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /opt/homebrew/Caskroom/miniforge/base/envs/ECG/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /opt/homebrew/Caskroom/miniforge/base/envs/ECG/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# /opt/homebrew/Caskroom/miniforge/base/envs/ECG/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     699         if ioargs.encoding and "b" not in ioargs.mode:
#     700             # Encoding
# --> 701             handle = open(
#     702                 handle,
#     703                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '2020_tokyo_olympics.csv'

# %%
final= pd.concat([data, tokyo], axis=0)
final=final.drop("Unnamed: 0",axis=1)
final
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-daa0c182ef33> in <module>
# ----> 1 final= pd.concat([data, tokyo], axis=0)
#       2 final=final.drop("Unnamed: 0",axis=1)
#       3 final
#
# NameError: name 'tokyo' is not defined

# %%
final
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-faec0869773a> in <module>
# ----> 1 final
#
# NameError: name 'final' is not defined

# %%
final.isnull().sum()
# Out:
# Name         0
# Sex          0
# Age       9474
# Team         0
# Games        0
# Year         0
# Season       0
# Sport        0
# Medal        0
# dtype: int64

# %%
final.head(100)
# Out:
#                                   Name Sex   Age            Team        Games  \
# 0                            A Dijiang   M  24.0           China  1992 Summer
# 1                             A Lamusi   M  23.0           China  2012 Summer
# 2                  Gunnar Nielsen Aaby   M  24.0         Denmark  1920 Summer
# 3                 Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  1900 Summer
# 4             Christine Jacoba Aaftink   F  21.0     Netherlands  1988 Winter
# ..                                 ...  ..   ...             ...          ...
# 95                Olav Augunson Aarnes   M  23.0          Norway  1912 Summer
# 96                 Mika Lauri Aarnikka   M  24.0         Finland  1992 Summer
# 97                 Mika Lauri Aarnikka   M  28.0         Finland  1996 Summer
# 98  Jamale (Djamel-) Aarrass (Ahrass-)   M  30.0          France  2012 Summer
# 99              Dagfinn Sverre Aarskog   M  24.0          Norway  1998 Winter
#
#     Year  Season          Sport  Medal
# 0   1992  Summer     Basketball      0
# 1   2012  Summer           Judo      0
# 2   1920  Summer       Football      0
# 3   1900  Summer     Tug-Of-War      3
# 4   1988  Winter  Speed Skating      0
# ..   ...     ...            ...    ...
# 95  1912  Summer      Athletics      0
# 96  1992  Summer        Sailing      0
# 97  1996  Summer        Sailing      0
# 98  2012  Summer      Athletics      0
# 99  1998  Winter      Bobsleigh      0
#
# [100 rows x 9 columns]

# %%
final.to_csv("Olympics_Dataset_(with_2020).csv")
